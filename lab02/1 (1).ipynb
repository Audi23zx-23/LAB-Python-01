# %%
edad = int(input("Ingrese su edad: "))
tiene_licencia = input("¿Tiene licencia? (s/n): ")
sanciones = input("¿Tiene alguna sancion? (s/n): ")

if edad >= 18 and tiene_licencia == "s" and sanciones == "n":
    print("Puede conducir")
else:
    print("No puede conducir")
# Out:
# Ingrese su edad: 19
# ¿Tiene licencia? (s/n): s
# ¿Tiene alguna sancion? (s/n): s
# No puede conducir
